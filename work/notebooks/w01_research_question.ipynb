# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/shivamkumarbhandari351/Machine_Learning_Intern_work/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
import os
REPO_URL = "https://github.com/shivamkumarbhandari351/Machine_Learning_Intern_work"
REPO_DIR = "Machine_Learning_Intern_work"

if not os.path.isdir(REPO_DIR):
    # !git clone --depth 1 {REPO_URL} {REPO_DIR}

os.chdir(REPO_DIR)
print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "CSV not found — check repo path"
print("Repo cloned and CSV found. Ready to go.")
# Out:
# Cloning into 'Machine_Learning_Intern_work'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 92 (delta 14), reused 66 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (92/92), 1.84 MiB | 17.00 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# Working dir: /content/Machine_Learning_Intern_work/Machine_Learning_Intern_work/Machine_Learning_Intern_work
# Repo cloned and CSV found. Ready to go.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# **Lane:** Marketing and Sales Analysis
#
# I chose this lane because businesses spend money on advertising and want to know whether it increases sales. By studying advertising data, I can find patterns that help businesses make better decisions about where to spend their marketing budget.

# %%
### 1. My lane (or freestyle) and why

#**Lane:** Marketing and Sales Analysis

#I chose this lane because businesses spend money on advertising and want to know whether it increases sales. By studying advertising data, I can find patterns that help businesses make better decisions about where to spend their marketing budget.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## 2. The question
#
# **Research Question:**
#
# How does advertising spending on TV, Radio, and Newspaper relate to product sales?
#
# **Decision Improved**
#
# This analysis helps businesses decide how to distribute their advertising budget.
#
# **Who Acts on It**
#
# Marketing managers and business owners.
#
# **Cost of a Wrong Recommendation**
#
# A poor recommendation may cause the company to spend money on ineffective advertising, reducing profit and missing potential customers.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

corr = df["search_volume"].corr(df["impressions_90d"])
print(f"1) Correlation search_volume vs impressions_90d: {corr:.3f} (near zero)")

visible = df[df["impressions_90d"] >= 100]
ctr_by_pos = visible.groupby("position_tier")["ctr"].mean().sort_values(ascending=False)
print("\n2) Mean CTR by position tier (impressions >= 100):")
print(ctr_by_pos.round(3))

wc = df.groupby("trend_direction")["word_count"].median()
print("\n3) Median word count by trend_direction:")
print(wc)

print("\nEffect size: page_1 CTR (~0.35) vs deep CTR (~0.06) is roughly a 6x gap —")
print("a large practical effect, not just a statistically detectable one.")
# Out:
# 1) Correlation search_volume vs impressions_90d: 0.001 (near zero)
#
# 2) Mean CTR by position tier (impressions >= 100):
# position_tier
# page_1      0.355
# top_3       0.334
# striking    0.256
# page_3_5    0.142
# deep        0.055
# Name: ctr, dtype: float64
#
# 3) Median word count by trend_direction:
# trend_direction
# down      2909.0
# flat      2698.5
# new       2239.0
# stable    2912.5
# up        2847.5
# Name: word_count, dtype: float64
#
# Effect size: page_1 CTR (~0.35) vs deep CTR (~0.06) is roughly a 6x gap —
# a large practical effect, not just a statistically detectable one.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## 4. Careful Words
#
# This project can identify observed relationships between advertising spending and sales. It can provide directional insights and support decision-making for marketing strategies.
#
# However, this project cannot prove that advertising directly causes changes in sales. It also cannot perfectly predict future sales or guarantee business outcomes because many other factors influence customer behavior.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
