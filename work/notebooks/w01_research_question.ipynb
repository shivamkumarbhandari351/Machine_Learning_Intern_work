# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/shivamkumarbhandari351/Machine_Learning_Intern_work/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
import os
from IPython.display import Markdown, display

# Construct the path to skills/README.md
# Assuming it's relative to the notebook's root or in a 'skills' directory
readme_path = 'data/raw/content_refresh_anonymized.csv'

if os.path.exists(readme_path):
    with open(readme_path, 'r') as f:
        readme_content = f.read()
    display(Markdown(f"""### Content of `{readme_path}`:
```markdown
{readme_content}
```
"""))
else:
    print(f"Could not find '{readme_path}'. Please ensure the file is present in the expected location.")
    print("To proceed, you might need to either upload the `skills` directory or adjust the `readme_path` variable.")
# Out:
# Could not find 'data/raw/content_refresh_anonymized.csv'. Please ensure the file is present in the expected location.
# To proceed, you might need to either upload the `skills` directory or adjust the `readme_path` variable.

# %%
import pandas as pd

# Define the path to the CSV file
csv_file_path = 'data/raw/content_refresh_anonymized.csv'

# Load the CSV file into a pandas DataFrame
try:
    df = pd.read_csv(csv_file_path)
    print(f"Successfully loaded '{csv_file_path}' into a DataFrame.")
    # Display the first 5 rows of the DataFrame
    display(df.head())
except FileNotFoundError:
    print(f"Error: The file '{csv_file_path}' was not found. Please ensure it's in the correct directory.")
except Exception as e:
    print(f"An error occurred while loading the CSV file: {e}")
# Out:
# Error: The file 'data/raw/content_refresh_anonymized.csv' was not found. Please ensure it's in the correct directory.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
